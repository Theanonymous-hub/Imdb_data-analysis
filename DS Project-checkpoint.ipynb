# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/IMDb movies.csv')
# Out:
# c:\users\acer\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# ...

# %%
df.head(10)
# Out:
#   imdb_title_id                                              title  \
# 0     tt0000009                                         Miss Jerry
# 1     tt0000574                        The Story of the Kelly Gang
# 2     tt0001892                                     Den sorte drøm
# 3     tt0002101                                          Cleopatra
# 4     tt0002130                                          L'Inferno
# 5     tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# 6     tt0002423                                     Madame DuBarry
# 7     tt0002445                                         Quo Vadis?
# 8     tt0002452                              Independenta Romaniei
# 9     tt0002461                                        Richard III
#
#                                       original_title  year date_published  \
# 0                                         Miss Jerry  1894     1894-10-09
# 1                        The Story of the Kelly Gang  1906     1906-12-26
# ...

# %%
df.shape
# Out:
# (85855, 22)

# %%
print("Number of Rows",data.shape[0])
print("Number of Rows",data.shape[1])
# Out:
# Number of Rows 85855
# Number of Rows 22

# %%
print("Number of Rows",data.shape[0])
print("Number of Columns",data.shape[1])
# Out:
# Number of Rows 85855
# Number of Columns 22

# %%
df.info
# Out:
# <bound method DataFrame.info of       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# ...

# %%
df.isnull()
# Out:
#        imdb_title_id  title  original_title   year  date_published  genre  \
# 0              False  False           False  False           False  False
# 1              False  False           False  False           False  False
# 2              False  False           False  False           False  False
# 3              False  False           False  False           False  False
# 4              False  False           False  False           False  False
# ...              ...    ...             ...    ...             ...    ...
# 85850          False  False           False  False           False  False
# 85851          False  False           False  False           False  False
# 85852          False  False           False  False           False  False
# 85853          False  False           False  False           False  False
# 85854          False  False           False  False           False  False
#
#        duration  country  language  director  ...  actors  description  \
# ...

# %%
data.isnull().sum()
# Out:
# imdb_title_id                0
# title                        0
# original_title               0
# year                         0
# date_published               0
# genre                        0
# duration                     0
# country                     64
# language                   833
# director                    87
# writer                    1572
# production_company        4455
# actors                      69
# description               2115
# avg_vote                     0
# votes                        0
# budget                   62145
# usa_gross_income         70529
# worlwide_gross_income    54839
# metascore                72550
# reviews_from_users        7597
# reviews_from_critics     11797
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
missing_val = df.isnull().sum() * 100 / len(data)
missing_val
# Out:
# imdb_title_id             0.000000
# title                     0.000000
# original_title            0.000000
# year                      0.000000
# date_published            0.000000
# genre                     0.000000
# duration                  0.000000
# country                   0.074544
# language                  0.970241
# director                  0.101334
# writer                    1.830994
# production_company        5.188981
# actors                    0.080368
# description               2.463456
# avg_vote                  0.000000
# votes                     0.000000
# budget                   72.383670
# usa_gross_income         82.148972
# worlwide_gross_income    63.873974
# metascore                84.502941
# reviews_from_users        8.848640
# reviews_from_critics     13.740609
# dtype: float64

# %%
df.dropna(axis=0)
# Out:
#       imdb_title_id                          title  \
# 506       tt0017136                     Metropolis
# 1048      tt0021749               Luci della città
# 2454      tt0027977                  Tempi moderni
# 2795      tt0029453        Il bandito della Casbah
# 2827      tt0029583      Biancaneve e i sette nani
# ...             ...                            ...
# 85266     tt9208444  Impractical Jokers: The Movie
# 85274     tt9214832                          Emma.
# 85397     tt9354944                           Jexi
# 85460     tt9426210            Weathering with You
# 85740     tt9779516            Cosa mi lasci di te
#
#                         original_title  year date_published  \
# 506                         Metropolis  1927     1928-10-01
# 1048                       City Lights  1931     1931-04-02
# 2454                      Modern Times  1936     1937-03-12
# 2795                      Pépé le Moko  1937     1937-10-22
# ...

# %%
duplicate_data=df.duplicated().any()
print("Is there any duplicate values?",duplicate_data)
# Out:
# Is there any duplicate values? False

# %%
df.describe(include='all')
# Out:
#        imdb_title_id  title original_title   year date_published  genre  \
# count          85855  85855          85855  85855          85855  85855
# unique         85855  82094          80852    168          22012   1257
# top        tt0000009   Anna           Anna   2017           2010  Drama
# freq               1     10             10   3223            113  12543
# mean             NaN    NaN            NaN    NaN            NaN    NaN
# std              NaN    NaN            NaN    NaN            NaN    NaN
# min              NaN    NaN            NaN    NaN            NaN    NaN
# 25%              NaN    NaN            NaN    NaN            NaN    NaN
# 50%              NaN    NaN            NaN    NaN            NaN    NaN
# 75%              NaN    NaN            NaN    NaN            NaN    NaN
# max              NaN    NaN            NaN    NaN            NaN    NaN
#
#             duration country language      director  ...  \
# ...

# %%
data[df['duration'] >=180] ['title']
# Out:
# 36                     The Perils of Pauline
# 47                    Nascita di una nazione
# 61                                 I vampiri
# 77                                     Judex
# 137                                 Tih Minh
#                         ...
# 85057                                La flor
# 85072       National Theatre Live: King Lear
# 85505                       Girl Blood Sport
# 85574                      Di Jiu Tian Chang
# 85629    National Theatre Live: Small Island
# Name: title, Length: 575, dtype: object

# %%
df.groupby('year')['avg_vote'].mean()
# Out:
# year
# 1894             5.900000
# 1906             6.100000
# 1911             6.140000
# 1912             5.980000
# 1913             6.546154
#                    ...
# 2017             5.698325
# 2018             5.687209
# 2019             5.709779
# 2020             5.377057
# TV Movie 2019    7.100000
# Name: avg_vote, Length: 168, dtype: float64

# %%
df.groupby('year')['avg_vote'].mean().sort_values(ascending=False)
# Out:
# year
# 1988    8.400000
# 1986    8.000000
# 1971    7.871429
# 1956    7.850000
# 1964    7.800000
#           ...
# 2015    5.558216
# 2005    5.513333
# 2013    5.482122
# 2020    5.377057
# 1989    5.000000
# Name: avg_vote, Length: 168, dtype: float64

# %%
sns.barplot(x='year',y='avg_vote',data=df)
plt.title("avg_votes by year")
plt.show()

# %%
df.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
#top10 lengthy movie
top10_len=df.nlargest(10,'duration')[['title','country','duration']]\
.set_index('title')
top10_len
# Out:
#                                                                  country  \
# title
# La flor                                                        Argentina
# Out 1, noli me tangere                                            France
# Khleb - imya sushchestvitelnoe                              Soviet Union
# Orbius                                                            Russia
# Ebolusyon ng isang pamilyang Pilipino                        Philippines
# Heremias: Libro primo                   Philippines, Netherlands, Sweden
# Kagadanan sa banwaan ning mga engkanto          Philippines, Netherlands
# Hele sa hiwagang hapis                            Philippines, Singapore
# Melancholia                                                  Philippines
# Hitler, un film dalla Germania                  West Germany, France, UK
#
#                                         duration
# title
# La flor                                      808
# Out 1, noli me tangere                       729
# ...

# %%
#Top10 lengthy movie
sns.barplot(x='duration',y=top10_len.index,data=top10_len)
# Out:
# <AxesSubplot:xlabel='duration', ylabel='title'>

# %%
df['year'].value_counts()
# Out:
# 2017    3223
# 2018    3182
# 2016    2992
# 2015    2764
# 2014    2517
#         ...
# 1989       1
# 1990       1
# 1978       1
# 1906       1
# 1988       1
# Name: year, Length: 168, dtype: int64

# %%
sns.countplot(x='year',data=df)
plt.title("Number of movies per year")
plt.show()

# %%
top10_len=data.nlargest(10,'votes')[['title','votes','director']]\
.set_index('title')
top10_len
# Out:
#                                                       votes  \
# title
# Le ali della libertà                                2278845
# Il cavaliere oscuro                                 2241615
# Inception                                           2002816
# Fight Club                                          1807440
# Pulp Fiction                                        1780147
# Forrest Gump                                        1755490
# Matrix                                              1632315
# Il Signore degli Anelli - La compagnia dell'Anello  1619920
# Il Signore degli Anelli - Il ritorno del re         1604280
# Il padrino                                          1572674
#
#                                                                            director
# title
# Le ali della libertà                                                 Frank Darabont
# Il cavaliere oscuro                                               Christopher Nolan
# ...

# %%
sns.barplot (x='votes', y=top10_len.index,data=top10_len ,hue='director',dodge=False)
plt.legend(bbox_to_anchor=(1.05,1),loc=2)

# %%
df.groupby('year')['avg_vote'].mean().sort_values(ascending=True)
# Out:
# year
# 1989    5.000000
# 2020    5.377057
# 2013    5.482122
# 2005    5.513333
# 2015    5.558216
#           ...
# 1964    7.800000
# 1956    7.850000
# 1971    7.871429
# 1986    8.000000
# 1988    8.400000
# Name: avg_vote, Length: 168, dtype: float64

# %%
df.groupby('year')['avg_vote'].mean().sort_values(ascending=True)
# Out:
# year
# 1989    5.000000
# 2020    5.377057
# 2013    5.482122
# 2005    5.513333
# 2015    5.558216
#           ...
# 1964    7.800000
# 1956    7.850000
# 1971    7.871429
# 1986    8.000000
# 1988    8.400000
# Name: avg_vote, Length: 168, dtype: float64

# %%
df.groupby(by=["year"])["avg_vote"].sum().plot(kind='bar',figsize=(20,15))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df['year'].value_counts().plot.pie(figsize=(70,20))
# Out:
# <AxesSubplot:ylabel='year'>

# %%
df['year'].value_counts()
# Out:
# 2017    3223
# 2018    3182
# 2016    2992
# 2015    2764
# 2014    2517
#         ...
# 1989       1
# 1990       1
# 1978       1
# 1906       1
# 1988       1
# Name: year, Length: 168, dtype: int64

# %%
df['year'].value_counts().plot(kind='line',xlabel='Year',ylabel='No. of movies released')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='No. of movies released'>

# %%
newdf=df.groupby(['genre','year']).size().to_frame().reset_index()
newdf.columns=['genres','year','no of movies released']
newdf
# Out:
#                 genres  year  no of movies released
# 0               Action  1940                      1
# 1               Action  1942                      1
# 2               Action  1964                      1
# 3               Action  1968                      1
# 4               Action  1969                      1
# ...                ...   ...                    ...
# 18289   Western, Drama  1971                      1
# 18290   Western, Drama  1975                      1
# 18291   Western, Drama  1979                      1
# 18292  Western, Family  1970                      1
# 18293  Western, Horror  1973                      1
#
# [18294 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          85855 non-null  object
#  1   title                  85855 non-null  object
#  2   original_title         85855 non-null  object
#  3   year                   85855 non-null  object
#  4   date_published         85855 non-null  object
#  5   genre                  85855 non-null  object
#  6   duration               85855 non-null  int64
#  7   country                85791 non-null  object
#  8   language               85022 non-null  object
#  9   director               85768 non-null  object
#  10  writer                 84283 non-null  object
#  11  production_company     81400 non-null  object
#  12  actors                 85786 non-null  object
#  13  description            83740 non-null  object
# ...

# %%
df['year']=df['year'].astype(np.object)
df['title']=df['title'].astype(np.object)
df['avg_vote']=df['avg_vote'].astype(np.int64)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          85855 non-null  object
#  1   title                  85855 non-null  object
#  2   original_title         85855 non-null  object
#  3   year                   85855 non-null  object
#  4   date_published         85855 non-null  object
#  5   genre                  85855 non-null  object
#  6   duration               85855 non-null  int64
#  7   country                85791 non-null  object
#  8   language               85022 non-null  object
#  9   director               85768 non-null  object
#  10  writer                 84283 non-null  object
#  11  production_company     81400 non-null  object
#  12  actors                 85786 non-null  object
#  13  description            83740 non-null  object
# ...

# %%
df.describe()
# Out:
#            duration      avg_vote         votes     metascore  \
# count  85855.000000  85855.000000  8.585500e+04  13305.000000
# mean     100.351418      5.452635  9.493490e+03     55.896881
# std       22.553848      1.271967  5.357436e+04     17.784874
# min       41.000000      1.000000  9.900000e+01      1.000000
# 25%       88.000000      5.000000  2.050000e+02     43.000000
# 50%       96.000000      6.000000  4.840000e+02     57.000000
# 75%      108.000000      6.000000  1.766500e+03     69.000000
# max      808.000000      9.000000  2.278845e+06    100.000000
#
#        reviews_from_users  reviews_from_critics
# count        78258.000000          74058.000000
# mean            46.040826             27.479989
# std            178.511411             58.339158
# min              1.000000              1.000000
# 25%              4.000000              3.000000
# 50%              9.000000              8.000000
# 75%             27.000000             23.000000
# ...
